# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'

# %%
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dados = pd.read_csv(url, sep =';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head(15)#15 primeiras linhas
# Out:
#                        Tipo               Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete           Copacabana        1      0       0
# 1                      Casa      Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala      Barra da Tijuca        0      4       0
# 3               Apartamento               Centro        1      0       0
# 4               Apartamento         Higienópolis        1      0       0
# 5               Apartamento         Vista Alegre        3      1       0
# 6               Apartamento             Cachambi        2      0       0
# 7        Casa de Condomínio      Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                Ramos        2      2       0
# 9   Conjunto Comercial/Sala               Centro        0      3       0
# 10              Apartamento               Centro        1      0       0
# 11              Apartamento               Grajaú        2      1       0
# ...

# %%
dados.tail(15)#15 ultimas linhas
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32945                Quitinete            Copacabana        1      0       0
# 32946  Conjunto Comercial/Sala                Centro        0      0       0
# 32947              Apartamento                Leblon        3      0       1
# 32948  Conjunto Comercial/Sala                Centro        0      0       0
# 32949              Apartamento               Ipanema        3      1       2
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.shape #gera uma tupla com o numero de linhas e colunas
# Out:
# (32960, 9)

# %%
dados.columns #gera os nomes e tipo
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados.info() #tras a quantidade de elementos nulos e seus tipos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados['Valor']
# Out:
# 0        1700.0
# 1        7000.0
# 2        5200.0
# 3         800.0
# 4         800.0
#           ...
# 32955     800.0
# 32956    1800.0
# 32957    1400.0
# 32958    3000.0
# 32959    6500.0
# Name: Valor, Length: 32960, dtype: float64

# %% [markdown]
# Qual o valor medio de aluguel por tipo de imovel

# %%
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean()
# Out:
# 12952.659715265761

# %%
dados.groupby('Tipo').mean(numeric_only = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2bca9318c11d> in <cell line: 1>()
# ----> 1 dados.groupby('Tipo').mean(numeric_only = True)
#
# NameError: name 'dados' is not defined

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preco_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# %%
df_preco_tipo.plot(kind = 'barh', figsize = (14, 10), color = 'red')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# REMOVENDO IMÓVEIS COMERCIAIS

# %%
dados.Tipo.unique() #verificar categorias da coluna
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados.query('@imoveis_comerciais in Tipo') #seleciona no df todos as linhas que possuem os itens da lista acima
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
dados.query('@imoveis_comerciais not in Tipo') #seleciona no df todos os iten da coluna 'Tipo' que não estão na lista 'imoveis_comerciais'
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
df_sem_imoveis_comerciais = dados.query('@imoveis_comerciais not in Tipo') #seleciona no df todos as linhas que possuem os itens da lista acima
df_sem_imoveis_comerciais.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_alterado = df_sem_imoveis_comerciais.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_alterado.plot(kind = 'barh', figsize = (14, 10), color = 'red')
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# QUAL O PERCENTUAL DE CADA TIPO DE IMOVEL NO DF

# %%
df_sem_imoveis_comerciais.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_sem_imoveis_comerciais.Tipo.value_counts(normalize=True)#value_counts, serve para contar
#quantas vezes cada item se repete, (o normalize serve para retornar em percentual)
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df_sem_imoveis_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo', ascending=False)
#to_frame transforma uma series em um data frame
#o "ascending = False" faz com que o df fique em ordem decrescente
# Out:
#                     proportion
# Tipo
# Studio                0.000173
# Quitinete             0.036173
# Loft                  0.002207
# Flat                  0.020596
# Casa de Vila          0.010774
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Apartamento           0.845139

# %%
df_percentual_tipo = df_sem_imoveis_comerciais.Tipo.value_counts(normalize=True).to_frame().sort_values('Tipo', ascending=False)
df_percentual_tipo.plot(kind = 'barh', figsize = (14, 10), color = 'red', ylabel = 'Tipos', xlabel = 'Percentual')
# Out:
# <Axes: xlabel='Percentual', ylabel='Tipos'>

# %% [markdown]
# DEVIDO AO GRANDE NÚMERO DE APARTAMENTOS, É PERCEBIDO QUE VALE A PENA TRABALHAR APENAS COM ESSES DADOS

# %%
df_apartamentos = df_sem_imoveis_comerciais.query('Tipo == "Apartamento"' )
df_apartamentos
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df_apartamentos['Quartos'].mean()
# Out:
# 2.481568707761622

# %%
df_apartamentos['Bairro'].count()
# Out:
# 19532

# %%
len(df_apartamentos['Bairro'].unique())
# Out:
# 149

# %%
df_aluguel_por_bairro = df_apartamentos.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending = False).head(5)
df_aluguel_por_bairro
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
df_aluguel_por_bairro.plot(kind = 'barh', figsize = (14, 10), color = 'red', ylabel = 'Bairros', xlabel = 'Aluguel Medio')
# Out:
# <Axes: xlabel='Aluguel Medio', ylabel='Bairros'>

# %%
df_apartamentos.isnull().sum()  #identificar valor nulos na tabela
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
df = df_apartamentos.fillna(0) #troca valores nulos por 0

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# REMOVENDO REGISTROS EM QUE O VALOR DE ALUGUEL E CONDOMÍNIO IGUAL A 0

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
reg_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(reg_remover, axis = 0, inplace = True)
#drop função que remove colunas ou linhas do df
#axis parametro que define se é linha(0) ou coluna(1)
#inplace faz a alteração direto no df, n necessitando armazenar numa variavel

# %%
df.query('Valor == 0 | Condominio == 0')
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# removendo coluna tipo, pois só tem o tipo apartamento

# %%
df.drop('Tipo', axis = 1, inplace = True)
df.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %% [markdown]
# Selecionando apartamentos que possuem 1 quarto e aluguel menor que 1200

# %%
selecao1 = df['Quartos'] == 1
df[selecao1]
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
selecao2 = df['Valor'] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_final = (selecao1) & (selecao2)
df[selecao_final]
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %% [markdown]
# APARTAMENTOS QUE POSSUEM AO MENOS 2 QUARTOS, ALUGUEL MENOR QUE 3000 E ÁREA > 70

# %%
remover2 = df.query('Valor >= 3000 | Quartos > 2 | Area <= 70').index
df.drop(remover2, axis = 0, inplace = True)
df
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 57     Recreio dos Bandeirantes        2      1       2    83  1600.0
# 67                     Maracanã        2      0       0    86  1800.0
# ...                         ...      ...    ...     ...   ...     ...
# 32881                   Taquara        2      1       1    71  1300.0
# 32890   Freguesia (Jacarepaguá)        2      1       1    87  1300.0
# 32933  Recreio dos Bandeirantes        2      1       1   105  2100.0
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
#
#        Condominio   IPTU
# 21          700.0  138.0
# 24          700.0    0.0
# 32          740.0    0.0
# ...

# %% [markdown]
# SALVANDO DADOS

# %%
df.to_csv('dados_apartamento.csv', index = False, sep = ';') #cria um arquivo csv com o dataframe
#index faz com que n crie uma coluna undefined
#sep faz com que o arquivo volte a ser separado por ponto e virgula

# %%
pd.read_csv('dados_apartamento.csv', sep = ';')
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0                       Tijuca        2      1       0   110  1900.0
# 1                       Tijuca        2      1       0    78  2000.0
# 2                     Botafogo        2      1       0    76  2500.0
# 3     Recreio dos Bandeirantes        2      1       2    83  1600.0
# 4                     Maracanã        2      0       0    86  1800.0
# ...                        ...      ...    ...     ...   ...     ...
# 2466                   Taquara        2      1       1    71  1300.0
# 2467   Freguesia (Jacarepaguá)        2      1       1    87  1300.0
# 2468  Recreio dos Bandeirantes        2      1       1   105  2100.0
# 2469               Jacarepaguá        2      1       1    78  2200.0
# 2470           Barra da Tijuca        2      1       1    85  2250.0
#
#       Condominio   IPTU
# 0          700.0  138.0
# 1          700.0    0.0
# 2          740.0    0.0
# 3         1160.0  157.0
# ...

# %% [markdown]
# COLUNAS NUMÉRICAS

# %%
url2 = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dadosN = pd.read_csv(url2, sep = ';')
dadosN.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dadosN['Valor_por_mes'] = dadosN['Valor'] + dadosN['Condominio'] #criando coluna valor por mes no df
dadosN.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dadosN['Valor_por_ano'] = dadosN['Valor_por_mes'] * 12 + dadosN['IPTU']
dadosN.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# COLUNAS CATEGORICAS

# %%
dadosN['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + \
                                        dados['Quartos'].astype(str) + ' quarto(s) ' + \
                                        ' e ' + dados['Vagas'].astype(str) + ' vaga(s) de garagem.'
dadosN.head()
#astype(str), troca o tipo da coluna para string, para que possa ser concatenada
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...
# ...

# %%
dados['Possui_suite'] = dados['Suites'].apply(lambda x: "Sim" if x > 0 else "Não")
dadosN.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao Possui_suite
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...          Não
# ...

# %% [markdown]
# PARA SABER MAIS SOBRE CRIAÇÃO DE COLUNAS

# %%
#Existem diversas maneiras de criar colunas em um DataFrame no Pandas. Alguns exemplos são:

#1 - Atribuição direta de valores a uma nova coluna:
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = [7, 8, 9]
df

#2 - Criação de uma coluna a partir de operações entre outras colunas:
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']
df

#3 - Utilização do método assign() para criar uma nova coluna:
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df = df.assign(C=[7, 8, 9])
df

#4 - Utilização do método apply() para aplicar uma função a uma coluna existente e criar uma nova coluna:
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'].apply(lambda x: x * 2)
df
