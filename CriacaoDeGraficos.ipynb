# %%
import matplotlib.pyplot as plt

# %%
estudantes = {
    "adib" : 100,
    "amelie" : 100,
    "Jp" : 300
}

# %%
plt.bar(x = estudantes.keys(), height = estudantes.values())
# Out:
# <BarContainer object of 3 artists>

# %%
from random import choices

# %% [markdown]
# CALCULO SEM USAR FUNÇÃO DE SOMA

# %%
soma = 0
for nota in estudantes.values():
  soma += nota

soma
# Out:
# 500

# %% [markdown]
# USANDO FUNÇÃO SUM(SOMA)

# %%
somaNotas = sum(estudantes.values())
somaNotas
# Out:
# 500

# %% [markdown]
# len(tamanho da lista

# %%
qtd_notas = len(estudantes)
qtd_notas
# Out:
# 3

# %% [markdown]
# MÉDIA

# %%
media = somaNotas / qtd_notas
media
# Out:
# 166.66666666666666

# %%
round(media)
# Out:
# 167

# %%
peso = float(input("Digite o peso, em quilogramas: "))
altura = float(input("Digite a altura, em metros: "))

imc = round(peso / pow(altura, 2), 2)

print(f"O IMC da pessoa é: {imc}")
# Out:
# Digite o peso, em quilogramas: 20
# Digite a altura, em metros: 2
# O IMC da pessoa é: 5.0

# %%
# Notas do(a) estudante
notas = [6.0, 7.0, 9.0, 5.5, 8.0]
qualitativo = 0.5

# %%
notas_atualizadas = map(lambda x: x + qualitativo, notas)
notas_atualizadas

# %%
list(notas_atualizadas)
# Out:
# [6.5, 7.5, 9.5, 6.0, 8.5]

# %%
lista = [16, 14, 63, 65, 17, 99, 70, 11, 20, 48, 79, 32, 17, 89, 12, 25, 66]

# %%
print(f'A lista possui {len(lista)} números em que o maior número é: {max(lista)} e o menor é: {min(lista)}')
# Out:
# A lista possui 17 números em que o maior número é: 99 e o menor é: 11

# %%
lista = [1, 2, 3, 4, 5]


def media(bla):
  media = sum(bla) / len(bla)
  return media

media(lista)
# Out:
# 3.0
